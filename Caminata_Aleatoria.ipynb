# %% [markdown]
# <a href="https://colab.research.google.com/github/danunive/Project/blob/master/Caminata_Aleatoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(123)
print(np.random.rand())
# Out:
# 0.6964691855978616

# %%
print(np.random.randint(1,7)) #7 is not included
# Out:
# 3

# %%
step = 50
dice = np.random.randint(1,7) #las posibilidades del dato
print(dice)
# Out:
# 5

# %%
if dice <= 2:
  step = step -1
elif dice <= 5:
  step = step +1
else :
  step = step +np.random.randint(1,7)

print(step)
# Out:
# 51

# %%
random_walk = [0]
for x in range(100): ##The loop should run 100 times
  step = random_walk[-1]
  dice = np.random.randint(1,7)

  if dice <=2:
    step = step -1
  elif dice <= 5:
    step = step +1
  else:
    step = step + np.random.randint(1,7)

  random_walk.append(step)  

print(random_walk)
# Out:
# [0, 1, 0, 1, 2, 3, 2, 1, 0, -1, -2, -3, -4, -5, -4, 1, 0, -1, 0, -1, 0, 1, 2, 3, 4, 3, 4, 3, 4, 5, 6, 7, 6, 10, 11, 10, 11, 10, 11, 12, 13, 14, 15, 16, 17, 20, 21, 22, 23, 28, 29, 33, 34, 33, 34, 35, 34, 35, 36, 38, 39, 40, 39, 38, 39, 40, 39, 38, 39, 40, 42, 41, 40, 41, 40, 41, 42, 43, 45, 44, 45, 46, 47, 48, 49, 48, 47, 48, 47, 48, 49, 48, 51, 52, 53, 54, 53, 54, 55, 59, 58]

# %%
random_walk = [0]
for x in range(100): ##The loop should run 100 times
  step = random_walk[-1]
  dice = np.random.randint(1,7)

  if dice <=2:
    step = step -1
  elif dice <= 5:
    step = step +1
  else:
    step = step + np.random.randint(1,7)

  random_walk.append(step)  

print(random_walk)
# Out:
# [0, -1, 1, 0, 1, 3, 4, 5, 10, 9, 10, 11, 12, 13, 14, 13, 18, 19, 20, 21, 20, 19, 18, 17, 16, 17, 18, 19, 25, 24, 23, 22, 23, 24, 25, 24, 25, 26, 25, 30, 31, 30, 29, 28, 27, 28, 27, 26, 28, 29, 32, 33, 35, 36, 37, 38, 37, 36, 37, 38, 39, 40, 39, 40, 41, 42, 45, 46, 47, 46, 47, 46, 47, 48, 49, 53, 52, 51, 52, 53, 54, 53, 54, 53, 54, 56, 61, 60, 61, 62, 63, 64, 65, 66, 65, 66, 67, 68, 70, 72, 71]

# %%
random_walk = [0]
for x in range(100): ##The loop should run 100 times
  step = random_walk[-1]
  dice = np.random.randint(1,7)

  if dice <=2:
    step = max(0,step -1) ## you can't go below 0!
  elif dice <= 5:
    step = step +1
  else:
    step = step + np.random.randint(1,7)

  random_walk.append(step)  

print(random_walk)

plt.plot(np.array(random_walk))
plt.show()
#np.array(random_walk)
# Out:
# [0, 1, 2, 5, 4, 5, 4, 5, 6, 7, 6, 7, 6, 7, 8, 10, 9, 8, 9, 10, 9, 11, 12, 13, 14, 15, 16, 17, 16, 17, 18, 23, 24, 23, 22, 21, 20, 21, 22, 23, 28, 29, 28, 29, 30, 31, 32, 33, 34, 33, 32, 33, 32, 38, 37, 38, 37, 38, 37, 38, 42, 46, 48, 50, 49, 50, 52, 51, 57, 58, 60, 61, 60, 61, 62, 63, 62, 63, 64, 65, 67, 66, 65, 66, 72, 77, 76, 75, 79, 80, 81, 82, 84, 83, 84, 83, 84, 83, 82, 88, 87]

# %%
# Initialize all_walks
all_walks = []

# Simulate random walk 10 times
for i in range (10) :

    # Code from before
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)

        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)

    # Append random_walk to all_walks
    all_walks.append(random_walk)

# Print all_walks
print(all_walks)
# Out:
# [[0, 1, 2, 3, 4, 5, 6, 7, 8, 7, 8, 7, 6, 7, 6, 7, 6, 7, 8, 12, 13, 12, 18, 17, 16, 17, 16, 15, 16, 15, 19, 18, 19, 18, 19, 18, 19, 21, 20, 19, 18, 19, 18, 23, 24, 25, 24, 23, 24, 23, 24, 23, 28, 29, 28, 27, 26, 25, 26, 27, 31, 37, 38, 39, 40, 41, 40, 41, 43, 44, 45, 46, 45, 44, 45, 44, 45, 46, 47, 46, 47, 48, 49, 48, 47, 48, 49, 54, 55, 56, 61, 60, 61, 60, 61, 62, 63, 64, 63, 69, 68], [0, 1, 0, 0, 1, 5, 6, 7, 8, 9, 8, 7, 6, 5, 4, 5, 6, 7, 8, 9, 10, 9, 10, 11, 10, 11, 12, 15, 14, 15, 14, 15, 18, 19, 20, 21, 20, 19, 22, 23, 24, 25, 24, 23, 24, 27, 28, 33, 34, 33, 34, 33, 34, 33, 39, 38, 37, 38, 40, 39, 38, 37, 38, 39, 40, 41, 45, 50, 51, 52, 53, 56, 57, 58, 59, 60, 61, 62, 61, 60, 61, 62, 61, 67, 66, 67, 68, 67, 66, 67, 66, 65, 71, 70, 69, 70, 71, 70, 69, 68, 67], [0, 1, 7, 8, 11, 12, 18, 19, 20, 26, 25, 31, 30, 31, 32, 33, 32, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 43, 44, 46, 45, 46, 45, 44, 45, 44, 45, 44, 48, 52, 51, 50, 49, 50, 51, 55, 56, 57, 61, 60, 59, 58, 59, 60, 62, 61, 60, 
# ...

# %%
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw = np.array(all_walks)
#print(np_aw)
# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)
#print(np_aw_t)
# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %%
n = np.array([[1,2,3],[2,3,3]])
plt.plot(n)
plt.show()

n_t = np.transpose(n)
print(n_t)
plt.plot(n_t)
plt.show()
# Out:
# [[1 2]
#  [2 3]
#  [3 3]]

# %%
# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand() <= 0.001 :
            step = 0
        
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()

ends = np_aw_t[-1, :]

ends = np_aw_t[-1, :]

# Plot histogram of ends, display plot
plt.hist(ends)
plt.show()
np.mean(ends>=60)
# Out:
# 0.782

# %% [markdown]
# np

# %%
print(np.count_nonzero(np_aw_t[-1, :] >= 60)/500)
# Out:
# 0.782

# %%
import pandas as pd
df = pd.DataFrame(ends)
print(df)

ruta = 'C:/Users/danaya/Desktop/datos.csv'
csv = df.to_csv(index=False)
# Out:
#       0
# 0    87
# 1    45
# 2    83
# 3    76
# 4    54
# ..   ..
# 495  81
# 496  67
# 497  81
# 498  98
# 499  88
#
# [500 rows x 1 columns]

# %% [markdown]
# # Nueva sección

# %%
df.to_csv('datos_histograma.csv')
